# %% [markdown]
# # Step 1: Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Step 2: Download and load the dataset

# %%
df = pd.read_csv("C:\\Project\\SQL\\tutorial\\pandas_practice\\advertising.csv")

df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # Step 3: Analayze the dataset

# %%
data = df.to_numpy()

tv = data[:, 0]
radio = data[:, 1]
newspaper = data[:, 2]
sales = data[:, -1]

# %% [markdown]
# ## Max sales value and its index

# %%
# YOUR CODE HERE
max_value = np.max(sales)
max_index = np.argmax(sales)
print(f"Max: {max_value} - Index: {max_index}")
print(sales[175])
# Out:
# Max: 27.0 - Index: 175
# 27.0

# %% [markdown]
# ## Mean of the TV column

# %%
# YOUR CODE HERE
mean_tv = tv.mean()
print(mean_tv)
# Out:
# 147.0425

# %% [markdown]
# ## Count records with Sales >= 20

# %%
# YOUR CODE HERE
cnt = sales[sales >= 20]
count = len(cnt)
print(count)
# Out:
# 40

# %% [markdown]
# ## Mean Radio spend where Sales is above average

# %%
# YOUR CODE HERE
abv_avg_sales = sales > np.average(sales)
mean_radio = np.mean(radio[abv_avg_sales])
print(mean_radio)
# Out:
# 26.005607476635515

# %% [markdown]
# ## Total Sales where Newspaper spend is above average

# %%
mean_newspaper = np.mean(newspaper)
# YOUR CODE HERE
sum_sales = np.sum(sales[newspaper > mean_newspaper])
print(sum_sales)
# Out:
# 1405.1
